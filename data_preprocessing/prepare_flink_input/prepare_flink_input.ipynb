# %%
import pandas as pd
from datetime import datetime

# %load_ext nb_black
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
df_sofa = pd.read_csv("data/sofa_data.csv")

# %%
for name, group in df_sofa.groupby("SUBJECT_ID"):
    try:
        df_signals = pd.read_csv(f"data/ts/signals_{name}.csv")
    except:
        continue
    print(name)
    df_merged = pd.merge(
        df_signals, group, left_on="TIME", right_on="CALCULATION_TIME", how="left"
    )
    first_timestamp = datetime.strptime(df_signals.iloc[0]["TIME"], "%Y-%m-%d %H:%M:%S")
    second_timestamp = datetime.strptime(
        df_signals.iloc[1]["TIME"], "%Y-%m-%d %H:%M:%S"
    )

    signal_length = int(60 * (second_timestamp - first_timestamp).total_seconds())
    last_valid_sofa_index = df_sofa["SOFA_SCORE"].last_valid_index()
    df_merged.loc[
        : last_valid_sofa_index + signal_length, "SOFA_SCORE"
    ] = df_merged.loc[: last_valid_sofa_index + signal_length, "SOFA_SCORE"].fillna(
        method="ffill"
    )

    df_merged[
        ["TIME", "HR", "ABPSYS", "ABPDIAS", "ABPMEAN", "RESP", "SPO2", "SOFA_SCORE"]
    ].to_csv(f"data/flink_input/signals_sofa_{name}.csv")
# Out:
# 24810
# 40013
# 40057
# 40083
# 40084
# 40133
# 40161
# 40227
# 40236
# 40435
# 40472
# 40706
# 40724
# 40828
# 40831
# 40833
# 40850
# 40867
# 40882
# 40900
# 40934
# 40950
# 41013
# 41022
# 41061
# 41163
# 41194
# 41266
# 41359
# 41405
# 41447
# 41546
# 41588
# 41589
# 41619
# 41782
# 41783
# 41844
# 41958
# 42049
# 42075
# 42130
# 42184
# 42210
# 42255
# 42311
# 42327
# 42364
# 42396
# 42397
# 42438
# 42477
# 42501
# 42509
# 42590
# 42621
# 42696
# 42800
# 42875
# 42904
# 43209
# 43220
# 43392
# 43447
# 43450
# 43559
# 43563
# 43571
# 43601
# 43613
# 43770
# 43837
# 43975
# 44018
# 44036
# 44059
# 44115
# 44164
# 44207
# 44319
# 44514
# 44534
# 44597
# 44600
# 44781
# 44788
# 44789
# 44807
# 44827
# 44870
# 44976
# 45138
# 45152
# 45300
# 45320
# 45346
# 45431
# 45531
# 45703
# 45774
# 45805
# 46156
# 46208
# 46217
# 46242
# 46252
# 46254
# 46415
# 46550
# 46695
# 46723
# 46728
# 46744
# 46851
# 46858
# 46927
# 46950
# 46968
# 47058
# 47146
# 47203
# 47287
# 47319
# 47543
# 47547
# 47613
# 47698
# 47733
# 47758
# 47967
# 47995
# 48006
# 48038
# 48118
# 48149
# 48239
# 48327
# 48351
# 48391
# 48480
# 48536
# 48580
# 48656
# 48688
# 48690
# 48707
# 48730
# 48732
# 48736
# 48774
# 48895
# 48936
# 48946
# 49038
# 49138
# 49261
# 49304
# 49311
# 49513
# 49520
# 49545
# 49583
# 49604
# 49613
# 49649
# 49780
# 49881
# 49970
# 50050
# 50089
# 50100
# 50182
# 50201
# 50217
# 50273
# 50302
# 50336
# 50387
# 50417
# 50447
# 50579
# 50729
# 50847
# 50880
# 51082
# 51121
# 51188
# 51202
# 51259
# 51301
# 51358
# 51374
# 51459
# 51482
# 51515
# 51519
# 51597
# 51790
# 51793
# 51858
# 51871
# 52011
# 52039
# 52146
# 52191
# 52238
# 52363
# 52436
# 52462
# 52503
# 52529
# 52556
# 52593
# 52710
# 52740
# 52766
# 52816
# 52846
# 52875
# 52897
# 52900
# 53036
# 53149
# 53247
# 53282
# 53283
# 53342
# 53404
# 53419
# 53425
# 53435
# 53462
# 53567
# 53594
# 53612
# 53632
# 53639
# 53707
# 53865
# 54088
# 54120
# 54147
# 54154
# 54183
# 54197
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-26c31ceb11c9> in <module>
#      21     )
#      22
# ---> 23     df_merged[
#      24         ["TIME", "HR", "ABPSYS", "ABPDIAS", "ABPMEAN", "RESP", "SPO2", "SOFA_SCORE"]
#      25     ].to_csv(f"data/flink_input/signals_sofa_{name}.csv")
#
# ~/venv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3034             indexer = np.where(indexer)[0]
#    3035
# -> 3036         data = self._take_with_is_copy(indexer, axis=1)
#    3037
#    3038         if is_single_key:
#
# ~/venv/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3598         See the docstring of `take` for full explanation of the parameters.
#    3599         """
# -> 3600         result = self.take(indices=indices, axis=axis)
#    3601         # Maybe set copy if we didn't actually change the index.
#    3602         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/venv/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3582         nv.validate_take((), kwargs)
#    3583
# -> 3584         self._consolidate_inplace()
#    3585
#    3586         new_data = self._mgr.take(
#
# ~/venv/lib/python3.8/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5539             self._mgr = self._mgr.consolidate()
#    5540
# -> 5541         self._protect_consolidate(f)
#    5542
#    5543     @final
#
# ~/venv/lib/python3.8/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5527         """
#    5528         blocks_before = len(self._mgr.blocks)
# -> 5529         result = f()
#    5530         if len(self._mgr.blocks) != blocks_before:
#    5531             self._clear_item_cache()
#
# ~/venv/lib/python3.8/site-packages/pandas/core/generic.py in f()
#    5537
#    5538         def f():
# -> 5539             self._mgr = self._mgr.consolidate()
#    5540
#    5541         self._protect_consolidate(f)
#
# ~/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     986         bm = type(self)(self.blocks, self.axes)
#     987         bm._is_consolidated = False
# --> 988         bm._consolidate_inplace()
#     989         return bm
#     990
#
# ~/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     991     def _consolidate_inplace(self) -> None:
#     992         if not self.is_consolidated():
# --> 993             self.blocks = tuple(_consolidate(self.blocks))
#     994             self._is_consolidated = True
#     995             self._known_consolidated = True
#
# ~/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1914     new_blocks: List[Block] = []
#    1915     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1916         merged_blocks = _merge_blocks(
#    1917             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1918         )
#
# ~/venv/lib/python3.8/site-packages/pandas/core/internals/managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1940
#    1941         argsort = np.argsort(new_mgr_locs)
# -> 1942         new_values = new_values[argsort]
#    1943         new_mgr_locs = new_mgr_locs[argsort]
#    1944
#
# MemoryError: Unable to allocate 334. MiB for an array with shape (15, 2915502) and data type float64
