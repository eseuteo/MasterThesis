# %%
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_interpolation = pd.read_csv("interpolation.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_interpolation["TIME_"] = df_interpolation["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_mean3h = pd.read_csv("mean_3h.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_mean3h["TIME_"] = df_mean3h["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_mean = pd.read_csv("mean.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_mean["TIME_"] = df_mean["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_mean30 = pd.read_csv("mean_30.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_mean30["TIME_"] = df_mean30["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_mean10 = pd.read_csv("mean_10.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_mean10["TIME_"] = df_mean10["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_mean5 = pd.read_csv("mean_5.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_mean5["TIME_"] = df_mean5["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_original = pd.read_csv("original.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_original["TIME_"] = df_original["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
mean = df_interpolation["value"].mean()

# %%
mean
# Out:
# 79.47749558413042

# %%
plt.figure(figsize=(18, 8), dpi=80)
plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
plt.plot(df_mean3h["TIME_"].iloc[:-100], df_mean3h["value"].iloc[:-100], linewidth=3, label = "Windowed Mean (window of 8 hours)")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.axhline(79.47749558413042, color="red", label="Original signal mean", linestyle="dashed")
plt.ylim(40, 120)
plt.legend()

# %%
df_original_resp = pd.read_csv("original_resp.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_original_resp["TIME_"] = df_original_resp["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_original_hr = pd.read_csv("original_hr.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_original_hr["TIME_"] = df_original_hr["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
df_correlation = pd.read_csv("hrrespcorrelation.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_correlation["TIME_"] = df_correlation["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
plt.figure(figsize=(18, 8), dpi=80)
plt.plot(df_original_resp["TIME_"], df_original_resp["value"], label = "Original RESP signal (normalized)")
plt.plot(df_original_hr["TIME_"], df_original_hr["value"], label = "Original HR signal (normalized)")
plt.plot(df_correlation["TIME_"], df_correlation["value"], linewidth=5, label = "Correlation coefficient")
plt.ylabel("Correlation Coefficient", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.legend()

# %%
df_entropy = pd.read_csv("entropy.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_entropy["TIME_"] = df_entropy["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
plt.figure(figsize=(18, 8), dpi=80)
#plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
plt.plot(df_entropy["TIME_"].iloc[:-100], df_entropy["value"].iloc[:-100], linewidth=3, label = "Windowed Mean (window of 8 hours)")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.legend()

# %%
plt.figure(figsize=(18, 8), dpi=80)
plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
#plt.plot(df_entropy["TIME_"].iloc[:-100], df_entropy["value"].iloc[:-100], linewidth=3, label = "Windowed Mean (window of 8 hours)")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.ylim(40,120)
plt.legend()

# %%
df_min = pd.read_csv("min.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_min["TIME_"] = df_min["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

df_max = pd.read_csv("max.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_max["TIME_"] = df_max["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

df_stdev = pd.read_csv("stdev_.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_stdev["TIME_"] = df_stdev["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
plt.figure(figsize=(18, 8), dpi=80)
plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
plt.plot(df_min["TIME_"], df_min["value"], linewidth=3, label = "Min value")
plt.plot(df_max["TIME_"], df_max["value"], linewidth=3, label = "Max value")
#plt.plot(df_stdev["TIME_"], df_stdev["value"], linewidth=3, label = "Standard Deviation")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.legend()

# %%
plt.figure(figsize=(18, 8), dpi=80)
plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
plt.plot(df_mean["TIME_"], df_mean["value"], linewidth=3, label = "Windowed Mean (1 hour)")
plt.plot(df_stdev["TIME_"], df_stdev["value"], linewidth=3, label = "Windowed Stdev (1 hour)")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.legend()

# %%
df_delta = pd.read_csv("deltas.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_delta["TIME_"] = df_delta["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

df_deltadelta = pd.read_csv("deltadeltas.csv", header=None, names=["TIME", "signal", "value", "asd"])
df_deltadelta["TIME_"] = df_deltadelta["TIME"].apply(lambda x: datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))

# %%
plt.figure(figsize=(18, 8), dpi=80)
#plt.plot(df_interpolation["TIME_"], df_interpolation["value"], label = "Original signal")
plt.plot(df_delta["TIME_"], df_delta["value"], linewidth=3, label = "Windowed Mean (1 hour)")
plt.plot(df_deltadelta["TIME_"], df_deltadelta["value"], linewidth=3, label = "Windowed Stdev (1 hour)")
plt.ylabel("ABPMean", fontsize=20)
plt.xlabel("Time", fontsize=20)
plt.legend()
